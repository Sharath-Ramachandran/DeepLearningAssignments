# %%
import matplotlib.pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
import pandas as pd
import numpy as np

# %%
def plotDecisionBoundary(weight, bias,randomVar):
    X, y = make_blobs(n_samples=100, centers=2, n_features=2,random_state=randomVar)
    df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
    colors = {0:'red', 1:'blue'}
    fig, ax = plt.subplots()
    grouped = df.groupby('label')
    for key, group in grouped:
        group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
    x_space = np.linspace(-10,10,100)
    y_space =-((weight[0]/weight[1])*x_space) -(bias/weight[1])
    plt.plot(x_space, y_space, '-', label='Test')
    plt.show()

# %%
def MakeDataset(randomVar):
    X, y = make_blobs(n_samples=100, centers=2, n_features=2,random_state=randomVar)
    df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
    colors = {0:'red', 1:'blue'}
    fig, ax = plt.subplots()
    grouped = df.groupby('label')
    for key, group in grouped:
        group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
    plt.show()
    return X,y

# %%
X,y = MakeDataset(10)
y[y==0]=-1
print(X[:5])
print(y[:5])
# Out:
# [[ 3.67982584  4.68165164]
#  [ 2.94713748  4.46116773]
#  [ 4.32968132  5.64396726]
#  [ 6.73488595 -9.38994773]
#  [ 2.44301805  3.84652646]]
# [ 1  1  1 -1  1]

# %%
len(y[y==1])
# Out:
# 50

# %%
# definition of the variables that are needed

# %%
learning_rate=0.01
weight=[0,0]#np.zeros(2)
bias=0
yDash=0
print("Weight vector is \n", weight)
# Out:
# Weight vector is
#  [0, 0]

# %%
X.shape
# Out:
# (100, 2)

# %%
count=0
didItChange=True
while didItChange is True and count<100:
    didItChange=False
    count=count+1
    #print("Weight is obtained as ",weight)
    for i in range(X.shape[0]):
        x=X[i]
        #x=np.expand_dims(x, axis=0)
        t=y[i]
        yDash=bias+(np.dot(weight,x))
        #print(yDash)
        #print(yDash)
        if(yDash>0):
            yDash=1.0
        else:
            yDash=-1.0
        #print(yDash,"  ",t)
        if yDash != t:
            #print("Comes here for ",yDash,"  ",t)
            didItChange=True
            weight=weight+learning_rate*x*t
            bias=bias+learning_rate*t
    plotDecisionBoundary(weight, bias,10)
    #print(count)

# %%
weight.shape
# Out:
# (2,)

# %%
#weight[0]=[-0.08051014,-0.09474832]

# %%
weight
# Out:
# array([0.03679826, 0.04681652])

# %%
bias
# Out:
# 0.01

# %%
# plotLine(weight,bias)
# X, y = make_blobs(n_samples=100, centers=2, n_features=2,random_state=50)
# df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
# colors = {0:'red', 1:'blue'}
# fig, ax = plt.subplots()
# grouped = df.groupby('label')
# for key, group in grouped:
#     group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
# x_space = np.linspace(-10,10,100)
# y_space =-(weight[0]/weight[1])*x-(bias/weight[1])
# plt.plot(x, y, '-', label='Test')
# plt.show()
plotDecisionBoundary(weight, bias,10)

# %%
# yDash=0
# for i in range((X.shape[0])):
#     x= X[i]
#     target= y[i]
#     x=np.expand_dims(x, axis=0)
#     yDash= bias+np.matmul(weight,x.T)
#     yDash=np.asscalar(yDash)
#     if(yDash>0.0):
#         # no updates required
#         weight=weight
#         bias=bias
#     else:
#         weight= weight+learning_rate*target*x
#         bias = bias+learning_rate*target

# %%
print(weight)
# Out:
# [0.03679826 0.04681652]
