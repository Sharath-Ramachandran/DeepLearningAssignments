# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %% [markdown]
# #### Low pass filter -- removes edges
# #### High pass filter -- complement of low pass filter(retains only the edges)

# %%
image1 = Image.open('Data/Data for Hybrid Images/cat.bmp').convert('L')
image2 = Image.open('Data/Data for Hybrid Images/dog.bmp').convert('L')

# %%
plt.imshow(image1,cmap='gray')

# %%
plt.imshow(image2,cmap='gray')
